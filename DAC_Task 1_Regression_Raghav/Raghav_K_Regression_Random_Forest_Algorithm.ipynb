# %%
import numpy as np 
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/2015.csv')
data
# Out:
#          Country  ... Dystopia Residual
# 0    Switzerland  ...           2.51738
# 1        Iceland  ...           2.70201
# 2        Denmark  ...           2.49204
# 3         Norway  ...           2.46531
# 4         Canada  ...           2.45176
# ..           ...  ...               ...
# 153       Rwanda  ...           0.67042
# 154        Benin  ...           1.63328
# 155        Syria  ...           0.32858
# 156      Burundi  ...           1.83302
# 157         Togo  ...           1.56726
#
# [158 rows x 12 columns]

# %% [markdown]
# Predeicting the datatypes of all the columns in the dataset using .dtypes()

# %%
data.dtypes
# Out:
# Region                                     object
# Happiness Rank                              int64
# Standard Error                            float64
# Economy (GDP per Capita)                  float64
# Family                                    float64
# Health (Life Expectancy)                  float64
# Freedom                                   float64
# Trust (Government Corruption)             float64
# Generosity                                float64
# Dystopia Residual                         float64
# Region_Australia and New Zealand            uint8
# Region_Central and Eastern Europe           uint8
# Region_Eastern Asia                         uint8
# Region_Latin America and Caribbean          uint8
# Region_Middle East and Northern Africa      uint8
# Region_North America                        uint8
# Region_Southeastern Asia                    uint8
# Region_Southern Asia                        uint8
# Region_Sub-Saharan Africa                   uint8
# ...

# %% [markdown]
# .head() is used to read the top 5 entries having the highest "Happiness Score" column

# %%
data.head()
# Out:
#        Country          Region  ...  Generosity  Dystopia Residual
# 0  Switzerland  Western Europe  ...     0.29678            2.51738
# 1      Iceland  Western Europe  ...     0.43630            2.70201
# 2      Denmark  Western Europe  ...     0.34139            2.49204
# 3       Norway  Western Europe  ...     0.34699            2.46531
# 4       Canada   North America  ...     0.45811            2.45176
#
# [5 rows x 12 columns]

# %% [markdown]
# .info() checks for missing and null values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# .nunique() function returns the unique columns in the dataset

# %%
data.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %% [markdown]
# .describe() function is used to calculate many of the data like mean, count, std

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  ...  Generosity  Dystopia Residual
# count      158.000000       158.000000  ...  158.000000         158.000000
# mean        79.493671         5.375734  ...    0.237296           2.098977
# std         45.754363         1.145010  ...    0.126685           0.553550
# min          1.000000         2.839000  ...    0.000000           0.328580
# 25%         40.250000         4.526000  ...    0.150553           1.759410
# 50%         79.500000         5.232500  ...    0.216130           2.095415
# 75%        118.750000         6.243750  ...    0.309882           2.462415
# max        158.000000         7.587000  ...    0.795880           3.602140
#
# [8 rows x 10 columns]

# %% [markdown]
# Check for null values

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# Prepare the data for training

# %%
X = data.iloc[:, 0:4].values
y = data.iloc[:, 4].values

# %% [markdown]
# Split the dataset into train and test dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# View the count of each class

# %%
y = data['Happiness Rank']
y.value_counts()
# Out:
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64

# %% [markdown]
# Visualize the R Square Method

# %%
plt.scatter(x,y,color="red")
plt.plot(x_,y_head,color="green")
plt.xlabel("Freedom to make life choices")
plt.ylabel("Perceptions of corruption")
plt.show()

# %% [markdown]
# Preprocessing the dataset

# %%
countries = list(set(data['Country'].values))
countries = sorted(countries)

# %%
data.head(20)
# Out:
#                  Country  ... Dystopia Residual
# 0            Switzerland  ...           2.51738
# 1                Iceland  ...           2.70201
# 2                Denmark  ...           2.49204
# 3                 Norway  ...           2.46531
# 4                 Canada  ...           2.45176
# 5                Finland  ...           2.61955
# 6            Netherlands  ...           2.46570
# 7                 Sweden  ...           2.37119
# 8            New Zealand  ...           2.26425
# 9              Australia  ...           2.26646
# 10                Israel  ...           3.08854
# 11            Costa Rica  ...           3.17728
# 12               Austria  ...           2.53320
# 13                Mexico  ...           3.60214
# 14         United States  ...           2.51011
# 15                Brazil  ...           3.26001
# 16            Luxembourg  ...           1.96961
# 17               Ireland  ...           1.97570
# 18               Belgium  ...           2.41484
# ...

# %%
one_hot_regions = pd.get_dummies(data['Region'], prefix = 'Region')
data = data.join(one_hot_regions)
df = data.drop(columns = 'Region')
df
# Out:
#          Country  ...  Region_Western Europe
# 0    Switzerland  ...                      1
# 1        Iceland  ...                      1
# 2        Denmark  ...                      1
# 3         Norway  ...                      1
# 4         Canada  ...                      0
# ..           ...  ...                    ...
# 153       Rwanda  ...                      0
# 154        Benin  ...                      0
# 155        Syria  ...                      0
# 156      Burundi  ...                      0
# 157         Togo  ...                      0
#
# [158 rows x 21 columns]

# %%
data = data.drop(columns = ['Country', 'Happiness Score'])
df = data.dropna(axis=0)
output = data['Happiness Rank']
df = data.drop(columns = ['Happiness Rank'])
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# Fix the preprocessors to the tree and evaluating the Random Forest algorithm

# %%
features = df.columns
percent = int(0.8 * len(data))
x = data[list(features)][:percent]
y = output[:percent]
x_test = df[list(features)][percent:]
y_test = output[percent:]
